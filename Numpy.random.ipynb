# %% [markdown]
# # The Numpy Random Package
# [Offical documentation](https://numpy.org/doc/stable/reference/random/index.html)
# ***

# %%
# Efficent for numerical arrays
import numpy as np
# Plotting
import matplotlib.pyplot as plt

# %%
# Change default style sheet
plt.style.use('fivethirtyeight')

# Change the default figure size
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 5]

# %% [markdown]
# <br>
#
# ## numpy.random.normal
#
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
#
# ***

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# %%
# Look at the first ten items.
s[:10]
# Out:
# array([ 0.01833471, -0.04074136,  0.00296212, -0.04230251,  0.23033206,
#        -0.06410965,  0.11553482,  0.11466221,  0.00500812, -0.01691898])

# %%
abs(mu - np.mean(s))
# Out:
# 0.0042744712746041425

# %%
abs(sigma - np.std(s, ddof=1))
# Out:
# 0.0017023891887379544

# %%
count, bins, ignored = plt.hist(s, 30, density=True)
f= 1/(sigma * np.sqrt(2 * np.pi))*np.exp( - (bins - mu)**2 / (2 * sigma**2))
plt.plot(bins, f, linewidth=2)
plt.show()

# %% [markdown]
# ## References
#     [1] https://www.datacamp.com/community/tutorials/numpy-random

# %% [markdown]
# ***
#
# ## End
